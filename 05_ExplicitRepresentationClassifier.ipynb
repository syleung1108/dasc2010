# %%
import numpy as np
import sympy as smp
import matplotlib.pyplot as plt
from scipy.integrate import *

# %%
t = smp.symbols('t')
r0 = smp.Matrix([1,1,0])
v = smp.Matrix([1,0,-1])
r = r0 + t*v
r
# Out:
# Matrix([
# [t + 1],
# [    1],
# [   -t]])

# %%
r = smp.Matrix([3*smp.cos(t/2), smp.sin(t/2), 2*t])
tt = np.linspace(0, 12.5, 100)
xx = 3*np.cos(tt/2)
yy = np.sin(tt/2)
zz = 2*tt
ax = plt.axes(projection='3d')
ax.plot3D(xx, yy, zz, 'red')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0.5, 0.5, 'y')

# %%
smp.diff(r,t)
# Out:
# Matrix([
# [-3*sin(t/2)/2],
# [   cos(t/2)/2],
# [            2]])

# %%
smp.diff(r,t,t)
# Out:
# Matrix([
# [-3*cos(t/2)/4],
# [  -sin(t/2)/4],
# [            0]])

# %%
v = smp.diff(r,t)
a = smp.diff(v,t)
theta = smp.acos(v.dot(a)/(v.norm()*a.norm())).simplify()
theta
# Out:
# acos(4*sin(t)/(sqrt(Abs(sin(t/2))**2 + 9*Abs(cos(t/2))**2)*sqrt(9*Abs(sin(t/2))**2 + Abs(cos(t/2))**2 + 16)))

# %%
theta.subs(t,5).evalf()
# Out:
# 1.92565432150379

# %%
tt = np.linspace(0, 10, 100)
aa = smp.lambdify([t], theta)(tt)
plt.plot(tt,aa)
plt.xlabel('$t$', fontsize=20)
plt.ylabel(r'$\theta(t)$', fontsize=20)
plt.show()

# %%
smp.integrate(r)
# Out:
# Matrix([
# [ 6*sin(t/2)],
# [-2*cos(t/2)],
# [       t**2]])

# %%
r = smp.Matrix([smp.exp(t**2)*smp.cos(t)**3,smp.exp(-t**4),1/(3+t**2)])

# %%
r_num = smp.lambdify([t], r)
quad_vec(r_num, 0, 5)[0]
# Out:
# array([[7.02141940e+07],
#        [9.06402477e-01],
#        [7.14368856e-01]])

# %%
r = smp.Matrix([smp.cos(t), smp.sin(t), t])
smp.integrate(smp.diff(r,t).norm(), (t,0,2*np.pi))
# Out:
# 8.88576587631673

# %%
r = smp.Matrix([smp.exp(t), smp.sin(t), t**4])
r_num = smp.lambdify([t], smp.diff(r,t).norm())
quad(r_num, 0, 1)[0]
# Out:
# 2.316977146444862
